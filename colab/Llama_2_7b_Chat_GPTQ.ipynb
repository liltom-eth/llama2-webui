# %% [markdown]
# <a href="https://colab.research.google.com/github/liltom-eth/llama2-webui/blob/main/colab/Llama_2_7b_Chat_GPTQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama2-wrapper

# %%
from llama2_wrapper import LLAMA2_WRAPPER, get_prompt

llama2_wrapper = LLAMA2_WRAPPER(
    backend_type="gptq",
)
# Out:
# Running on GPU with backend torch transformers.
# Model path is empty.
# Use default gptq model path: ./models/Llama-2-7b-Chat-GPTQ
# Start downloading model to: ./models/Llama-2-7b-Chat-GPTQ
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# ...
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# WARNING:accelerate.utils.modeling:The safetensors archive passed at ./models/Llama-2-7b-Chat-GPTQ/gptq_model-4bit-128g.safetensors does not contain metadata. Make sure to save your model with the `save_pretrained` method. Defaulting to 'pt' metadata.
# WARNING:auto_gptq.nn_modules.fused_llama_mlp:skip module injection for FusedLlamaMLPForQuantizedModel not support integrate without triton yet.

# %%
prompt = get_prompt("Hi do you know Pytorch?")
print(llama2_wrapper(prompt))
# Out:
#   Yes, I'm familiar with PyTorch! PyTorch is an open-source machine learning library developed by Facebook that provides a dynamic computation graph and is particularly well-suited for deep learning tasks. It is built on top of the Torch library and is primarily used for developing neural networks and their associated algorithms.
# Here are some key features of PyTorch:
#
# 1. **Dynamic Computation Graph**: PyTorch's computation graph is dynamic, which means that it can be built and modified at runtime. This allows for more flexible and efficient computation, especially in deep learning tasks.
# 2. **Tensor Algebra**: PyTorch provides a powerful tensor algebra system that allows for easy manipulation of tensors. This makes it easy to define and optimize neural networks.
# 3. **Autograd**: PyTorch's autograd system automatically computes gradients, which saves time and effort compared to manual computation.
# ...

# %%
# %cd /content
# !git clone https://github.com/liltom-eth/llama2-webui
# %cd /content/llama2-webui
# !python benchmark.py --backend_type gptq
# Out:
# /content
# fatal: destination path 'llama2-webui' already exists and is not an empty directory.
# /content/llama2-webui
# Running on GPU with backend torch transformers.
# Model path is empty.
# Use default gptq model path: ./models/Llama-2-7b-Chat-GPTQ
# Model exists in ./models/Llama-2-7b-Chat-GPTQ
# 2023-08-15 23:50:49.173114: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# The safetensors archive passed at ./models/Llama-2-7b-Chat-GPTQ/gptq_model-4bit-128g.safetensors does not contain metadata. Make sure to save your model with the `save_pretrained` method. Defaulting to 'pt' metadata.
# skip module injection for FusedLlamaMLPForQuantizedModel not support integrate without triton yet.
# Performing cold run...
# Performing 5 timed runs...
#   0% 0/5 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# ...
